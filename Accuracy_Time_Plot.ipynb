# %%
import matplotlib.pyplot as plt
# line 1 points
x1 = ['BOW', 'tf-idf', 'bigram', 'trigram']
y1 = [3.85,3.17,13.08,16.06]
# plotting the line 1 points 
plt.plot(x1, y1, label = "Naive Bayes")
# line 2 points
x2 = ['BOW', 'tf-idf', 'bigram', 'trigram']
y2 = [25.58,55.81, 97.91, 112.19]
# plotting the line 2 points 
plt.plot(x2, y2, label = "SVM")
# line 3 points
x3 = ['BOW', 'tf-idf', 'bigram', 'trigram']
y3 = [19.21,13.44,93.71,121.74]
# plotting the line 2 points 
plt.plot(x3, y3, label = "RF")
# line 4 points
x4 = ['BOW', 'tf-idf', 'bigram', 'trigram']
y4 = [81.8,17.49,88.67,174.29]
# plotting the line 2 points 
plt.plot(x4, y4, label = "MLR")

plt.xlabel('Feature type')
# Set the y axis label of the current axis.
plt.ylabel("Time taken to train model(sec)")
# Set a title of the current axes.
plt.title('Time taken to train different model on different feature types')
# show a legend on the plot
plt.legend()
# Display a figure.
plt.show()

# %%
import matplotlib.pyplot as plt
# line 1 points
x1 = ['BOW', 'tf-idf', 'bigram', 'trigram']
y1 = [94.8,88.6,99.4,99.6]
# plotting the line 1 points 
plt.plot(x1, y1, label = "Naive Bayes")
# line 2 points
x2 = ['BOW', 'tf-idf', 'bigram', 'trigram']
y2 = [97.7,91.6, 98.3, 98.4]
# plotting the line 2 points 
plt.plot(x2, y2, label = "SVM")
# line 3 points
x3 = ['BOW', 'tf-idf', 'bigram', 'trigram']
y3 = [98.8,73.4,99.6,99.2]
# plotting the line 2 points 
plt.plot(x3, y3, label = "RF")
# line 4 points
x4 = ['BOW', 'tf-idf', 'bigram', 'trigram']
y4 = [99.0,90.7,99.5,99.8]
# plotting the line 2 points 
plt.plot(x4, y4, label = "MLR")

plt.xlabel('Feature type')
# Set the y axis label of the current axis.
plt.ylabel("Accuracy")
# Set a title of the current axes.
plt.title('Time taken to train different model on different feature types')
# show a legend on the plot
plt.legend()
# Display a figure.
plt.show()

# %%
import matplotlib.pyplot as plt
# line 1 points
y1 = [3.85,3.17,13.08,16.06]
x1 = [94.8,88.6,99.4,99.6]
# plotting the line 1 points 
plt.plot(x1, y1, label = "Naive Bayes")
# line 2 points
y2 = [25.58,55.81, 97.91, 112.19]
x2 = [97.7,91.6, 98.3, 98.4]
# plotting the line 2 points 
plt.plot(x2, y2, label = "SVM")
# line 3 points
y3 = [19.21,13.44,93.71,121.74]
x3 = [98.8,73.4,99.6,99.2]
# plotting the line 2 points 
plt.plot(x3, y3, label = "RF")
# line 4 points
y4 = [81.8,17.49,88.67,174.29]
x4 = [99.0,90.7,99.5,99.8]
# plotting the line 2 points 
plt.plot(x4, y4, label = "MLR")

plt.xlabel('Accuracy')
# Set the y axis label of the current axis.
plt.ylabel("Time Taken in seconds")
# Set a title of the current axes.
plt.title('Time taken to train different model on different feature types')
# show a legend on the plot
plt.legend()
# Display a figure.
plt.show()
